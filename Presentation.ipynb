# %%
''' Qualifier Type '''
class Qualifier:
    def __init__(self):
        pass

class Linear(Qualifier):
    def __init__(self):
        pass

class Unlimited(Qualifier):
    def __init__(self):
        pass

''' Var Type '''
Var = str

''' Ty Type '''
class Ty :
    def __init__(self, ty):
        self.ty = ty
        
class TyBool(Ty):
        def __init__(self):
            pass
            
class TyEnd(Ty):
        def __init__(self):
            pass
            
class TyQual(Ty): 
    def __init__(self, qual,pre):
        self.qual = qual
        self.pre = pre

''' PreType Class '''
class PreType:
    def __init__(self, pre):
        self.pre = pre

class TyRecv(PreType):
    def __init__(self, ty1, ty2= None):
        self.ty1 = ty1
        self.ty2 = ty2
        
class TySend(PreType):
    def __init__(self, ty1, ty2 = None):
        self.ty1 = ty1
        self.ty2 = ty2

''' Value Type'''
class Value:
    def __init__(self):
        self.child = []

class Variable(Value):
    def __init__(self, item):
        self.item = item
    
class VBool(Value):
    def __init__(self, item):
        self.item = item

''' Channel Type '''
class Channel:
    def __init__(self, name):
        self.name = name 

''' Process Type '''
class Process:
    def __init__(self):
        self.child = []
        pass

class Output(Process):
    def __init__(self, channel, value, process):
        self.channel = channel
        self.value = value
        self.process = process
        

class Input(Process):
    def __init__(self, qualifier, channel, variable, process):
        self.qualifier = qualifier
        self.channel = channel
        self.variable = variable
        self.process = process
        
        
class Par(Process):
    def __init__(self, process1, process2):
        self.process1 = process1
        self.process2 = process2

class If(Process):
    def __init__(self, value, process1, process2):
        self.value = value
        self.process1 = process1
        self.process2 = process2
        
class Inaction(Process):
    def __init__(self):
        pass

class ScopeRestriction(Process):
    def __init__(self, channel1, channel2, ty, process):
        self.channel1 = channel1
        self.channel2 = channel2
        self.ty = ty
        self.process = process

class Program(Process):
    def __init__(self, child):
        self.child = child
    def add(node):
        if child == None:
            child = []
        else:
            child.append(node)

# %%
from pyparsing import *
import unittest
import collections
import xml.etree.ElementTree as ET
from xmltodict import *


linear = Group(Literal('lin'))("LinearNode")
unlimited = Group(Literal('un'))("UnNode")
qualifier = Group(linear | unlimited)("QualifierNode")

pre = Forward()
tybool = Group('bool')("TyBoolNode")
tyend = Group('end')("TyEndNode")
tyqual = Group(qualifier+pre)("TyQualNode")
ty =  Group(tybool | tyend | tyqual)("TyNode")

recv = Group('?'+ty+'.'+ty)("TyRecvNode")
send = Group('!'+ty+'.'+ty)("TySendNode")
pre << Group(recv | send)("PreTypeNode")

var = Group(Word( alphas+"*", alphanums+"*" ))("VariableNode")
vbool =  Group(Literal('true')|Literal('false'))("VBoolNode")
val = Group(vbool | var)("ValueNode")

channel = Group(var)("ChannelNode")

process = Forward()
outputt = Group(channel+val+Literal(".")+process)("OutputNode") # DO THIS
inputt = Group(qualifier+channel+Literal("(")+var+Literal(")")+Literal(".")+process)("InputNode")
par = Group(Literal("[")+process+Literal("|")+process+Literal("]"))("ParNode")
conditional = Group(Literal("if")+val+Literal("then")+process+Literal("else")+process)("IfNode") 
inaction = Group(Literal("0"))("InactionNode") #Done
screst = Group(Literal("(W")+channel+channel+ty+Literal(")")+process)("ScRestNode")
process << Group(outputt | inputt | par | conditional | inaction| screst)("ProcessNode")
program = OneOrMore(process | val)

class TypeNode():
    def __init__(self, root=None):
        self.root = root
        self.child = []
    
    def addChild(self, c):
        self.child.append(c)
        
def createNode(xmlroot):
    tag = xmlroot.tag
    
    if tag == "QualifierNode":
        return createNode(xmlroot[0])
    if tag == "UnNode":
        return Unrestricted()
    if tag == "LinearNode":
        return Linear()
    if tag == "TyNode":
        return createNode(xmlroot[0])
    if tag == "TyBoolNode":
        return TyBool()
    if tag == "TyEndNode":
        return TyEnd()
    if tag == "TyQualNode":
        return TyQual(createNode(xmlroot[0]), createNode(xmlroot[1]))
    if tag == "PreTypeNode":
        return createNode(xmlroot[0])
    if tag == "TyRecvNode":
        ty1 = createNode(xmlroot[0])
        ty3 = createNode(xmlroot[3])
        return TyRecieve(ty1, ty3)
    if tag == "TySendNode":
        ty1 = createNode(xmlroot[0])
        ty3 = createNode(xmlroot[3])
        return TySend(ty1, ty3)
    if tag == "ProcessNode":
        p = Process()
        for c in xmlroot:
            p.child.append(createNode(c))
        return p
    if tag == "InactionNode":
        return Inaction()
    if tag == "InputNode":
        qualifier = createNode(xmlroot[0])
        channel = createNode(xmlroot[1])
        variable = createNode(xmlroot[3])
        process = createNode(xmlroot[6])
        return Input(qualifier, channel, variable, process)
    if tag == "OutputNode":
        channel = createNode(xmlroot[0])
        value = createNode(xmlroot[1])
        process = createNode(xmlroot[3])
        return Output(channel, value, process)
    if tag == "ParNode":
        process1 = createNode(xmlroot[1])
        process2 = createNode(xmlroot[3])
        return Par(process1, process2)
    if tag == "ChannelNode":
        return Channel(createNode(xmlroot[0]))
    if tag == "VariableNode":
        return Variable(xmlroot[0].text)
    if tag == "VBoolNode":
        return VBool(xmlroot[0].text)
    if tag == "ValueNode":
        v = Value()
        for c in xmlroot:
            v.child.append(createNode(c))
        return v
    if tag == "IfNode":
        value = createNode(xmlroot[1])
        process1 = createNode(xmlroot[3])
        process2 = createNode(xmlroot[5])
        return If(value, process1, process2)
    if tag == "ScRestNode":
        channel1 = createNode(xmlroot[1])
        channel2 = createNode(xmlroot[2])
        ty = createNode(xmlroot[3])
        process = createNode(xmlroot[5])
        return ScopeRestriction(channel1, channel2, ty, process)
    else:
        return None
    
def XMLToTypeTree(xmlroot):
    tree = TypeNode()
    node = createNode(xmlroot)
    
    if xmlroot is None:
        return None
    
    if node is None:
        return None
    
    else:
        tree.root = node
        
    for c in xmlroot:
        #print 'Child:' + str(c)  + ' T:' + str(c.tag) + ' Parent:' + str(tree) + ' T:' + str(xmlroot.tag)
        childTree = XMLToTypeTree(c)
        if childTree:
            tree.addChild(childTree)
    return tree

# %%
import copy

### Test Strings ### 
inString = "0" # Done
opString = "x* v."+inString # Done
ipString = "lin x (x)."+inString #Done
parString = "["+ipString+"|"+opString+"]" #Done
ifString = "if true then "+opString+" else "+ipString #Done
sdrestString = "(W x1 x2 bool)"+opString

def getTree(string, toPrint = False):
    ps = program.parseString(string)
    xmldata = ps.asXML()
    
    root = ET.fromstring(xmldata)
    tree = createNode(root)
    
    if toPrint:
        print xmldata
        
    return tree

# %%
''' Type Checker '''

import types
from functools import reduce
from patterns import patterns, Mismatch
import string

# Map of key value pairs

class Context:
    def __init__(self):
        self.env = {}
        self.LinFreeVars = []

@patterns
def isUnlimited():
    if t is TyQual:
        print "Is Ty Qual"
        print t.qual
        if isinstance(t.qual,Linear):
            print "Is Linear"
            return False
        else:
            print "Is Unlimited"
            return True
    else:
        return True

def consume(name , st):
    ''' If in consume must be a linear variable '''
    if name in st.env:
        value = copy.copy(st.env[name])
        pretype = value.pre
        
        ''' Checking if whole of PreType is used '''
        if isinstance(pretype, PreType):
            if( pretype.ty2 != None):
                ivalue = copy.copy(pretype.ty2)
                pretype.ty1 = pretype.ty2
                pretype.ty2 = None
                value.pre = pretype
                st.env[name] = value
                return (ivalue, st)
        
        del st.env[name]
        return (value, st)
    
    return False

def printMap(env):
    for k, v in env :
        print "Key: ", k, "Value",v 

def areDual(t1, t2):
    return (isinstance(t1, TyRecv) and isinstance(t2, TySend) ) or (isinstance(t1, TySend) and isinstance(t2, TyRecv))
        
def typeCheckVal(t, st):
    if isinstance(t, Channel):
        print "Getting channel typechecked", t.name
        return typeCheckVal(t.name, st)
    if isinstance(t, Variable):
        if(t.item in st.env):
            ty = st.env[t.item]
            if isUnlimited( ty ):
                return(ty, st)
            else:
                ty, s1= consume(t.item, st)
                print "After consume ty: ", ty," s1: ", s1
                s1 = copy.copy(s1) # This is to ensure that the result persists
                return (ty, s1) 
        else:
            raise Exception("Unbound type variable ")
    if isinstance(t, VBool):
        print "TypeChecking VBool"
        return (TyBool(), st)
    if isinstance(t, Value):
        return typeCheckVal(t.child[0], st)

def typeCheckProcess(t, st):
    if isinstance(t, Inaction):
        print "In Inaction"
        return st
    
    if isinstance(t, Output):
        print "In Output"
        ty, st = typeCheckVal(t.channel, st)
        if(isinstance(ty.pre, TySend)):
            ty1, st1 = typeCheckVal(t.value, st)
            print type(ty1)
            print type(ty.pre.ty1)
            if type(ty1) != type(ty.pre.ty1):
                raise Exception("No match between Send Type and Value Type")
            else:
                return typeCheckProcess(t.process, st1)
        else:
            raise Exception("Pretype is not send")
            
    if isinstance(t, Input):
        print "In Input T: ",t," St :",st
        print "Channel has type",t.channel
        ty, st = typeCheckVal(t.channel, st)
        print "Type : ", ty
        if(isinstance(ty.pre, TyRecv)):
            ty1, st1 = typeCheckVal(t.variable, st)
            if type(ty1) != type(ty.pre.ty1):
                raise Exception("No match between Recieve Type and Value Type")
            else:
                return typeCheckProcess(t.process, st1)
        else:
            raise Exception("Pretype is not recieve")
        return st
    
    if isinstance(t, ScopeRestriction):
        # Check if Dual Types
        print "In Scope Restriction"
        c1 =  st.env[t.channel1.name.item].pre
        c2 =  st.env[t.channel2.name.item].pre
        if ( areDual(c1, c2) ):
            print "Dual Channels"
            return typeCheckProcess(t.process, st)
        else:
            raise Exception("Channels are not dual")
    if isinstance(t, Par):
        print "TypeChecking Parallel Processes"
        st1 = typeCheckProcess(t.process1, st)
        return typeCheckProcess(t.process2, st1)
    if isinstance(t, If):
        print "TypeChecking If Process"
        condition = t.value.child[0].item
        if condition == "true":
            print "In Condition 1"
            return typeCheckProcess(t.process1, st)
        else:
            return typeCheckProcess(t.process2, st)   
    if isinstance(t, Process):
        return typeCheckProcess(t.child[0], st)
        
def typeCheck(t, st):
    if isinstance(t, Value):
        print "Type checking Value"
        result = []
        try:
            s1 = copy.copy(st)
            for c in t.child:
                r = typeCheckVal(c, s1)
                result.append(r)
            print("---- Result : TypeChecking Success ---")
            return result
        
        except Exception:
            print ("Type Checker failed ")
            
        else:
            print("In else block")
        
    
    if isinstance(t, Process):
        print("TypeChecking Process")
        result = []
        try:
            s1 = copy.copy(st)
            for c in t.child:
                r = typeCheckProcess(c, s1)
                result.append(r)
            
            print("---- Result : TypeChecking Success ---")
            return result
        e

# %%
''' First Example Simple Send Value '''

example1 = "x* true x*"
tree = getTree(example1, False)
ctx = Context()
ctx.env["x*"] =  TyQual( Linear(), TySend(TyBool()) )
typeCheck(tree, ctx)
#print octxt
# Out:
# <ValueNode>
#   <ValueNode>
#     <VariableNode>
#       <ITEM>x*</ITEM>
#     </VariableNode>
#   </ValueNode>
#   <ValueNode>
#     <VBoolNode>
#       <ITEM>true</ITEM>
#     </VBoolNode>
#   </ValueNode>
#   <ValueNode>
#     <VariableNode>
#       <ITEM>x*</ITEM>
#     </VariableNode>
#   </ValueNode>
# </ValueNode>
# Type checking Value
# Is Ty Qual
# <__main__.Linear instance at 0x104c7c290>
# Is Linear
# After consume ty:  <__main__.TyQual instance at 0x104c39680>  s1:  <__main__.Context instance at 0x104cf2cf8>
# TypeChecking VBool
# Type Checker failed
# [(<__main__.TyQual instance at 0x104c39680>,
#   <__main__.Context instance at 0x104c39638>),
#  (<__main__.TyBool instance at 0x104c39200>,
#   <__main__.Context instance at 0x104cf2cf8>)]

# %%
''' Second Example Simple Recieve Value '''

example2 = "y true y"
tree = getTree(example2)
ctx = Context()
ctx.env["y"] =  TyQual( Linear(),  TyRecv( TyBool(), TyBool() ) )
octxt = typeCheck(tree, ctx)
# Out:
# Type checking Value
# Is Ty Qual
# <__main__.Linear instance at 0x104d2f170>
# Is Linear
# After consume ty:  <__main__.TyBool instance at 0x104d1c440>  s1:  <__main__.Context instance at 0x104d2fc68>
# TypeChecking VBool
# Is Ty Qual
# <__main__.Linear instance at 0x104d2f170>
# Is Linear
# After consume ty:  <__main__.TyQual instance at 0x104d1cdd0>  s1:  <__main__.Context instance at 0x104d2fc68>
# ---- Result : TypeChecking Success ---

# %%
''' Third Example Simple Inaction Process '''

example3 = "0"
tree = getTree(example3)

ctx = Context()
ctx.env["x*"] =  TyQual( Linear(),  TySend( TyBool() ) )

octxt = typeCheck(tree, ctx)
for c in octxt:
    print c.env
# Out:
# TypeChecking Process
# In Inaction
# ---- Result : TypeChecking Success ---
# {'x*': <__main__.TyQual instance at 0x104cbed40>}

# %%
''' Both Send and Recieve - Linear / Unlimited Types '''

example = "y* x"
tree = getTree(example)
print tree
ctx = Context()
ctx.env["x"] =  TyQual( Linear(),  TyRecv( TyBool() ) )
ctx.env["y*"] =  TyQual( Unlimited(),  TySend( TyBool() ) )
octxt = typeCheck(tree, ctx)
# Out:
# <__main__.Value instance at 0x104d34518>
# Type checking Value
# Is Ty Qual
# <__main__.Unlimited instance at 0x104ca3d88>
# Is Unlimited
# Is Ty Qual
# <__main__.Linear instance at 0x104c39200>
# Is Linear
# After consume ty:  <__main__.TyQual instance at 0x104d1c440>  s1:  <__main__.Context instance at 0x104d1cdd0>
# ---- Result : TypeChecking Success ---

# %%
''' Output Channel Example '''

opString = "x* true . 0"
tree = getTree(opString, False)
print tree
    
ctx = Context()
ctx.env["x*"] =  TyQual( Unlimited(),  TySend( TyBool() ) )
ctx.env["y"] =  TyQual( Linear(),  TyRecv( TyBool() ) )
# ctx.env["y*"] =  TyQual( Unlimited(),  TyRecv( TyBool() ) )
octxt = typeCheck(tree, ctx)
print octxt[0].env
# Out:
# <__main__.Process instance at 0x104d1c6c8>
# TypeChecking Process
# In Output
# Getting channel typechecked <__main__.Variable instance at 0x104d1cd40>
# Is Ty Qual
# <__main__.Unlimited instance at 0x104d1c830>
# Is Unlimited
# TypeChecking VBool
# <type 'instance'>
# <type 'instance'>
# In Inaction
# ---- Result : TypeChecking Success ---
# {'x*': <__main__.TyQual instance at 0x104cd9b90>, 'y': <__main__.TyQual instance at 0x104cd5d88>}

# %%
''' Input channel example '''
ipString = "lin x (y). 0"
tree = getTree(ipString, True)

    
ctx = Context()
ctx.env["x"] =  TyQual( Linear(),  TyRecv( TyBool() ) )
ctx.env["y"] =  TyQual( Unlimited(),  TyRecv( TyBool() ) )
octxt = typeCheck(tree, ctx)
# Out:
# <ProcessNode>
#   <ProcessNode>
#     <InputNode>
#       <QualifierNode>
#         <LinearNode>
#           <ITEM>lin</ITEM>
#         </LinearNode>
#       </QualifierNode>
#       <ChannelNode>
#         <VariableNode>
#           <ITEM>x</ITEM>
#         </VariableNode>
#       </ChannelNode>
#       <ITEM>(</ITEM>
#       <VariableNode>
#         <ITEM>y</ITEM>
#       </VariableNode>
#       <ITEM>)</ITEM>
#       <ITEM>.</ITEM>
#       <ProcessNode>
#         <InactionNode>
#           <ITEM>0</ITEM>
#         </InactionNode>
#       </ProcessNode>
#     </InputNode>
#   </ProcessNode>
# </ProcessNode>
# TypeChecking Process
# In Input T:  <__main__.Input instance at 0x104cd50e0>  St : <__main__.Context instance at 0x104d1cd40>
# Channel has type <__main__.Channel instance at 0x104cd56c8>
# Getting channel typechecked <__main__.Variable instance at 0x104cd5908>
# Is Ty Qual
# <__main__.Linear instance at 0x104cd5128>
# Is Linear
# After consume ty:  <__main__.TyQual instance at 0x104d1c050>  s1:  <__main__.Context instance at 0x104d1cd40>
# Type :  <__main__.TyQual instance at 0x104d1c050>
# Is Ty Qual
# <__main__.Unlimited instance at 0x104d1c6c8>
# Is Unlimited
# In Inaction
# ---- Result : TypeChecking Success ---

# %%
example = "(W x* y bool) "+opString
tree = getTree(example, False)
    
ctx = Context()
ctx.env["x*"] =  TyQual( Linear(),   TySend( TyBool() ) )
ctx.env["y"] =  TyQual( Unlimited(),  TyRecv( TyBool(), TyBool()) )
octxt = typeCheck(tree, ctx)
# Out:
# TypeChecking Process
# In Scope Restriction
# Dual Channels
# In Output
# Getting channel typechecked <__main__.Variable instance at 0x104c4bcb0>
# Is Ty Qual
# <__main__.Linear instance at 0x104c4b290>
# Is Linear
# After consume ty:  <__main__.TyQual instance at 0x104cd5e18>  s1:  <__main__.Context instance at 0x104cd50e0>
# TypeChecking VBool
# <type 'instance'>
# <type 'instance'>
# In Inaction
# ---- Result : TypeChecking Success ---

# %%
example = "["+opString+"|"+ipString+"] "
tree = getTree(example, False)
print opString
print ipString

ctx = Context()
ctx.env["x*"] =  TyQual( Linear(),  TySend( TyBool() ) )
ctx.env["x"] =  TyQual( Linear(),  TyRecv( TyBool() ) )
ctx.env["y"] =  TyQual( Unlimited(),  TyRecv( TyBool() ) )
octxt = typeCheck(tree, ctx)
# Out:
# x* true . 0
# lin x (y). 0
# TypeChecking Process
# TypeChecking Parallel Processes
# In Output
# Getting channel typechecked <__main__.Variable instance at 0x104d2f998>
# Is Ty Qual
# <__main__.Linear instance at 0x104d1cc68>
# Is Linear
# After consume ty:  <__main__.TyQual instance at 0x104c4b488>  s1:  <__main__.Context instance at 0x104c4b5f0>
# TypeChecking VBool
# <type 'instance'>
# <type 'instance'>
# In Inaction
# In Input T:  <__main__.Input instance at 0x104cbb680>  St : <__main__.Context instance at 0x104d1c9e0>
# Channel has type <__main__.Channel instance at 0x104cf2c68>
# Getting channel typechecked <__main__.Variable instance at 0x104d2f950>
# Is Ty Qual
# <__main__.Linear instance at 0x104c7c290>
# Is Linear
# After consume ty:  <__main__.TyQual instance at 0x104d1cc68>  s1:  <__main__.Context instance at 0x104d1c9e0>
# Type :  <__main__.TyQual instance at 0x104d1cc68>
# Is Ty Qual
# <__main__.Unlimited instance at 0x104c62d88>
# Is Unlimited
# In Inaction
# ---- Result : TypeChecking Success ---

# %%
example = "["+opString+"|"+ipString+"] "
tree = getTree(example, False)
print opString
print ipString

ctx = Context()
ctx.env["x*"] =  TyQual( Linear(),  TySend( TyBool() ) )
ctx.env["x"] =  TyQual( Linear(),  TyRecv( TyBool() ) )
ctx.env["y"] =  TyQual( Unlimited(),  TyRecv( TyBool() ) )
octxt = typeCheck(tree, ctx)
# Out:
# x* true . 0
# lin x (y). 0
# TypeChecking Process
# TypeChecking Parallel Processes
# In Output
# Getting channel typechecked <__main__.Variable instance at 0x104d34e18>
# Is Ty Qual
# <__main__.Linear instance at 0x104cf2c68>
# Is Linear
# After consume ty:  <__main__.TyQual instance at 0x104d2fc20>  s1:  <__main__.Context instance at 0x104d2f950>
# TypeChecking VBool
# <type 'instance'>
# <type 'instance'>
# In Inaction
# In Input T:  <__main__.Input instance at 0x104d34b48>  St : <__main__.Context instance at 0x104d2f050>
# Channel has type <__main__.Channel instance at 0x104d340e0>
# Getting channel typechecked <__main__.Variable instance at 0x104d34320>
# Is Ty Qual
# <__main__.Linear instance at 0x104cf27e8>
# Is Linear
# After consume ty:  <__main__.TyQual instance at 0x104cf2c68>  s1:  <__main__.Context instance at 0x104d2f050>
# Type :  <__main__.TyQual instance at 0x104cf2c68>
# Is Ty Qual
# <__main__.Unlimited instance at 0x104d2ffc8>
# Is Unlimited
# In Inaction
# ---- Result : TypeChecking Success ---

# %%
example = "if true then"+opString+"else"+ipString
tree = getTree(example, False)

print tree
ifnode =  tree.child[0].child[0]
print ifnode.value, ifnode.process1, ifnode.process2
print ifnode.value.child[0].item 

ctx = Context()
ctx.env["x*"] =  TyQual( Linear(),  TySend( TyBool() ) )
ctx.env["x"] =  TyQual( Linear(),  TyRecv( TyBool() ) )
ctx.env["y"] =  TyQual( Unlimited(),  TyRecv( TyBool() ) )
octxt = typeCheck(tree, ctx)

print octxt[0].env
# Out:
# <__main__.Process instance at 0x104d2f560>
# <__main__.Value instance at 0x104d2f680> <__main__.Process instance at 0x104d1cab8> <__main__.Process instance at 0x104d1cf38>
# true
# TypeChecking Process
# TypeChecking If Process
# In Condition 1
# In Output
# Getting channel typechecked <__main__.Variable instance at 0x104d1c758>
# Is Ty Qual
# <__main__.Linear instance at 0x104c4b488>
# Is Linear
# After consume ty:  <__main__.TyQual instance at 0x104ca33b0>  s1:  <__main__.Context instance at 0x104ca36c8>
# TypeChecking VBool
# <type 'instance'>
# <type 'instance'>
# In Inaction
# ---- Result : TypeChecking Success ---
# {'x': <__main__.TyQual instance at 0x104ca3d40>, 'y': <__main__.TyQual instance at 0x104ca32d8>}
