# %%
from pyparsing import *
import unittest
import collections
import xml.etree.ElementTree as ET
from xmltodict import *


linear = Group(Literal('lin'))("LinearNode")
unlimited = Group(Literal('un'))("UnNode")
qualifier = Group(linear | unrestricted)("QualifierNode")

pre = Forward()
tybool = Group('bool')("TyBoolNode")
tyend = Group('end')("TyEndNode")
tyqual = Group(qualifier+pre)("TyQualNode")
ty =  Group(tybool | tyend | tyqual)("TyNode")

recv = Group('?'+ty+'.'+ty)("TyRecvNode")
send = Group('!'+ty+'.'+ty)("TySendNode")
pre << Group(recv | send)("PreTypeNode")

var = Group(Word( alphas+"*", alphanums+"*" ))("VariableNode")
vbool =  Group(Literal('true')|Literal('false'))("VBoolNode")
val = Group(vbool | var)("ValueNode")

channel = Group(var)("ChannelNode")

process = Forward()
outputt = Group(channel+val+Literal(".")+process)("OutputNode") # DO THIS
inputt = Group(qualifier+channel+Literal("(")+var+Literal(")")+Literal(".")+process)("InputNode")
par = Group(Literal("[")+process+Literal("|")+process+Literal("]"))("ParNode")
conditional = Group(Literal("if")+val+Literal("then")+process+Literal("else")+process)("IfNode") 
inaction = Group(Literal("0"))("InactionNode") #Done
screst = Group(Literal("(W")+channel+channel+ty+Literal(")")+process)("ScRestNode")
process << Group(outputt | inputt | par | conditional | inaction| screst)("ProcessNode")
program = OneOrMore(process | val)

class TypeNode():
    def __init__(self, root=None):
        self.root = root
        self.child = []
    
    def addChild(self, c):
        self.child.append(c)
        
def createNode(xmlroot):
    print "In createNode"
    tag = xmlroot.tag
    if tag == "QualifierNode":
        return createNode(xmlroot[0])
    if tag == "UnNode":
        return Unrestricted()
    if tag == "LinearNode":
        return Linear()
    if tag == "TyNode":
        return createNode(xmlroot[0])
    if tag == "TyBoolNode":
        return TyBool()
    if tag == "TyEndNode":
        return TyEnd()
    if tag == "TyQualNode":
        return TyQual(createNode(xmlroot[0]), createNode(xmlroot[1]))
    if tag == "PreTypeNode":
        return createNode(xmlroot[0])
    if tag == "TyRecvNode":
        ty1 = createNode(xmlroot[0])
        ty3 = createNode(xmlroot[3])
        return TyRecieve(ty1, ty3)
    if tag == "TySendNode":
        ty1 = createNode(xmlroot[0])
        ty3 = createNode(xmlroot[3])
        return TySend(ty1, ty3)
    if tag == "ProcessNode":
        p = Process()
        for c in xmlroot:
            p.child.append(createNode(c))
        return p
    if tag == "InactionNode":
        return Inaction()
    if tag == "InputNode":
        qualifier = createNode(xmlroot[0])
        channel = createNode(xmlroot[1])
        variable = createNode(xmlroot[3])
        process = createNode(xmlroot[6])
        return Input(qualifier, channel, variable, process)
    if tag == "OutputNode":
        channel = createNode(xmlroot[0])
        value = createNode(xmlroot[1])
        process = createNode(xmlroot[3])
        return Output(channel, value, process)
    if tag == "ParNode":
        process1 = createNode(xmlroot[1])
        process2 = createNode(xmlroot[3])
        return Par(process1, process2)
    if tag == "ChannelNode":
        name = createNode(xmlroot[0])
        return Channel(name)
    if tag == "VariableNode":
        return Variable(xmlroot[0].text)
    if tag == "VBoolNode":
        return VBool(xmlroot[0].text)
    if tag == "ValueNode":
        v = Value()
        for c in xmlroot:
            v.child.append(createNode(c))
        return v
    if tag == "IfNode":
        value = createNode(xmlroot[1])
        process1 = createNode(xmlroot[3])
        process2 = createNode(xmlroot[5])
        return If(value, process1, process2)
    if tag == "ScRestNode":
        channel1 = createNode(xmlroot[1])
        channel2 = createNode(xmlroot[2])
        ty = createNode(xmlroot[3])
        process = createNode(xmlroot[5])
        return ScopeRestriction(channel1, channel2, ty, process)
    else:
        return None
    
def XMLToTypeTree(xmlroot):
    tree = TypeNode()
    node = createNode(xmlroot)
    
    if xmlroot is None:
        return None
    
    if node is None:
        return None
    
    else:
        tree.root = node
        
    for c in xmlroot:
        #print 'Child:' + str(c)  + ' T:' + str(c.tag) + ' Parent:' + str(tree) + ' T:' + str(xmlroot.tag)
        childTree = XMLToTypeTree(c)
        if childTree:
            tree.addChild(childTree)
    return tree

# %%
import copy

### Test Strings ### 
inString = "0" # Done
opString = "x* v."+inString # Done
ipString = "lin x (x)."+inString #Done
parString = "["+ipString+"|"+opString+"]" #Done
ifString = "if true then "+opString+" else "+ipString #Done
sdrestString = "(W x1 x2 bool)"+opString

def getTree(string, toPrint = False):
    ps = program.parseString(string)
    xmldata = ps.asXML()
    
    root = ET.fromstring(xmldata)
    tree = createAST(root)
    
    if toPrint:
        print xmldata

    return tree

def getContext(octxt):
    for ctx in octxt:
        print ctx[0], ctx[1].env

t = getTree(ipString, False)
print t
print t.child
print t.child[0]
print t.child[0][1]
# Out:
# In createAST
# In createNode
# In createNode
# In createNode
# In createNode
# In createNode
# In createNode
# In createNode
# In createNode
# In createNode
# <__main__.Process instance at 0x1050fcb90>
# [<__main__.Process instance at 0x1050fc758>]
# <__main__.Process instance at 0x1050fc758>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-621-bdf5a4394c1d> in <module>()
#      29 print t.child
#      30 print t.child[0]
# ---> 31 print t.child[0][1]
#
# AttributeError: Process instance has no attribute '__getitem__'

# %%
''' Type Checker '''

import types
from functools import reduce
from patterns import patterns, Mismatch
import string

# Map of key value pairs

class Context:
    def __init__(self):
        self.env = {}
        self.LinFreeVars = []

@patterns
def isUnlimited():
    if t is TyQual:
        print "Is Ty Qual"
        print t.qual
        if isinstance(t.qual,Linear):
            print "Is Linear"
            return False
        else:
            print "Is Unlimited"
            return True
    else:
        return True

def consume(name , st):
    ''' If in consume must be a linear variable '''
    if name in st.env:
        value = copy.copy(st.env[name])
        pretype = value.pre
        
        ''' Checking if whole of PreType is used '''
        if isinstance(pretype, PreType):
            if( pretype.ty2 != None):
                ivalue = copy.copy(pretype.ty2)
                pretype.ty1 = pretype.ty2
                pretype.ty2 = None
                value.pre = pretype
                st.env[name] = value
                return (ivalue, st)
        
        del st.env[name]
        return (value, st)
    
    return False

def printMap(env):
    for k, v in env :
        print "Key: ", k, "Value",v 

def areDual(t1, t2):
    return (isinstance(t1, TyRecv) and isinstance(t2, TySend) ) or (isinstance(t1, TySend) and isinstance(t2, TyRecv))
        
def typeCheckVal(t, st):
    if isinstance(t, Channel):
        print "Getting channel typechecked", t.name
        return typeCheckVal(t.name, st)
    if isinstance(t, Variable):
        if(t.item in st.env):
            ty = st.env[t.item]
            if isUnlimited( ty ):
                return(ty, copy.copy(st))
            else:
                ty, s1= consume(t.item, st)
                print "After consume ty: ", ty," s1: ", s1
                s1 = copy.copy(s1) # This is to ensure that the result persists
                return (ty, s1) 
        else:
            raise Exception("Unbound type variable ")
    if isinstance(t, VBool):
        print "TypeChecking VBool"
        return (TyBool(), st)

def typeCheckProcess(t, st):
    if isinstance(t, Inaction):
        print "In Inaction"
        return st
    
    if isinstance(t, Output):
        print "In Output"
        ty, st = typeCheckVal(t.c, st)
        if(isinstance(ty.pre, TySend)):
            ty1, st1 = typeCheckVal(t.value, st)
            print type(ty1)
            print type(ty.pre.ty1)
            if type(ty1) != type(ty.pre.ty1):
                raise Exception("No match between Send Type and Value Type")
            else:
                return typeCheckProcess(t.process, st1)
        else:
            raise Exception("Pretype is not send")
            
    if isinstance(t, Input):
        print "In Input T: ",t," St :",st
        print "Channel has type",t.channel
        ty = typeCheckVal(t.channel, st)
        print "Type : ", ty
        if(isinstance(ty.pre, TyRecieve)):
            print t.value
            ty1, st1 = typeCheckVal(t.value, st)
            if type(ty1) != type(ty.pre.ty1):
                raise Exception("No match between Recieve Type and Value Type")
            else:
                return typeCheckProcess(t.process, st1)
        else:
            raise Exception("Pretype is not recieve")
        return st
    
    if isinstance(t, ScopeRestriction):
        # Check if Dual Types
        print "In Scope Restriction"
        c1 =  st.env[t.channel1.name.item].pre
        c2 =  st.env[t.channel2.name.item].pre
        if ( areDual(c1, c2) ):
            print "Dual Channels"
            return typeCheckProcess(t.process, st)
        else:
            raise Exception("Channels are not dual")
    if isinstance(t, Par):
        return st
    if isinstance(t, If):
        return st
        
def typeCheck(t, st):
    if isinstance(t, Value):
        print "Type checking Value"
        result = []
        s1 = copy.copy(st)
        for c in t.child:
            r = typeCheckVal(c, s1)
            result.append(r)
        
        print("---- Result : TypeChecking Success ---")
        return result
    
    if isinstance(t, Process):
        print("TypeChecking Process")
        result = []
        s1 = copy.copy(st)
        for c in t.child:
            r = typeCheckProcess(c, s1)
            result.append(r)
            
        print("---- Result : TypeChecking Success ---")
        return result

# %%
example1 = "x* true"
tree = getTree(example1)
ctx = Context()
ctx.env["x*"] =  TyQual( Unrestricted(), TySend(TyBool()) )
octxt  = typeCheck(tree, ctx)
print "Getting results: "
getContext(octxt)
# Out:
# Type checking Value
# Is Ty Qual
# <__main__.Unrestricted instance at 0x104fa93f8>
# Is Unlimited
# TypeChecking VBool
# ---- Result : TypeChecking Success ---
# Getting results:
# <__main__.TyQual instance at 0x104952cb0> {'x*': <__main__.TyQual instance at 0x104952cb0>}
# <__main__.TyBool instance at 0x104952c68> {'x*': <__main__.TyQual instance at 0x104952cb0>}

# %%
example2 = "x* true x*"
tree = getTree(example2)
ctx = Context()
ctx.env["x*"] =  TyQual( Linear(),  TySend( TyBool(), TyBool() ) )
octxt = typeCheck(tree, ctx)
# Out:
# Type checking Value
# Is Ty Qual
# <__main__.Linear instance at 0x1049043b0>
# Is Linear
# After consume ty:  <__main__.TyBool instance at 0x104c949e0>  s1:  <__main__.Context instance at 0x104904680>
# TypeChecking VBool
# Is Ty Qual
# <__main__.Linear instance at 0x1049043b0>
# Is Linear
# After consume ty:  <__main__.TyQual instance at 0x104c94878>  s1:  <__main__.Context instance at 0x104904680>
# ---- Result : TypeChecking Success ---

# %%
example3 = "0"
tree = getTree(example3)

ctx = Context()
ctx.env["x*"] =  TyQual( Linear(),  TySend( TyBool() ) )

octxt = typeCheck(tree, ctx)
for c in octxt:
    print c.env
# Out:
# TypeChecking Process
# In Inaction
# ---- Result : TypeChecking Success ---
# {'x*': <__main__.TyQual instance at 0x104952cb0>}

# %%
example = "y* x"
tree = getTree(example)
print tree
ctx = Context()
ctx.env["x"] =  TyQual( Linear(),  TyRecv( TyBool() ) )
ctx.env["y*"] =  TyQual( Unlimited(),  TySend( TyBool() ) )
octxt = typeCheck(tree, ctx)
# Out:
# <__main__.Value instance at 0x104c94a70>
# Type checking Value
# Is Ty Qual
# <__main__.Unlimited instance at 0x104e192d8>
# Is Unlimited
# Is Ty Qual
# <__main__.Linear instance at 0x104904128>
# Is Linear
# After consume ty:  <__main__.TyQual instance at 0x104dbb5a8>  s1:  <__main__.Context instance at 0x104c942d8>
# ---- Result : TypeChecking Success ---

# %%
opString = "x* true . 0"
tree = getTree(opString, False)
print tree

for c in tree.child:
    print c.channel, c.value, c.process
    
ctx = Context()
ctx.env["x*"] =  TyQual( Linear(),  TySend( TyBool() ) )
ctx.env["y"] =  TyQual( Linear(),  TyRecv( TyBool() ) )
# ctx.env["y*"] =  TyQual( Unlimited(),  TyRecv( TyBool() ) )
octxt = typeCheck(tree, ctx)
print octxt[0].env
# Out:
# <__main__.Process instance at 0x104ca02d8>
# <__main__.Channel instance at 0x104ca0710> <__main__.VBool instance at 0x104ca0f38> <__main__.Inaction instance at 0x104c94488>
# TypeChecking Process
# In Output
# Is Ty Qual
# <__main__.Linear instance at 0x104c3c950>
# Is Linear
# After consume ty:  <__main__.TyQual instance at 0x104cffea8>  s1:  <__main__.Context instance at 0x104dbb950>
# <__main__.TyQual instance at 0x104cffea8>
# TypeChecking VBool
# <type 'instance'>
# <type 'instance'>
# In Inaction
# ---- Result : TypeChecking Success ---
# {'y': <__main__.TyQual instance at 0x104c94b48>}

# %%
ipString = "lin x* (true). 0"
tree = getTree(ipString, True)

for c in tree.child:
    print c.channel, c.variable, c.process
    
#ctx = Context()
#ctx.env["x*"] =  TyQual( Linear(),  TyRecv( TyBool() ) )
#ctx.env["y"] =  TyQual( Unlimited(),  TyRecv( TyBool() ) )
#octxt = typeCheck(tree, ctx)
#print octxt[0].env
# Out:
# <ProcessNode>
#   <ProcessNode>
#     <InputNode>
#       <QualifierNode>
#         <LinearNode>
#           <ITEM>lin</ITEM>
#         </LinearNode>
#       </QualifierNode>
#       <ChannelNode>
#         <VariableNode>
#           <ITEM>x*</ITEM>
#         </VariableNode>
#       </ChannelNode>
#       <ITEM>(</ITEM>
#       <VariableNode>
#         <ITEM>true</ITEM>
#       </VariableNode>
#       <ITEM>)</ITEM>
#       <ITEM>.</ITEM>
#       <ProcessNode>
#         <InactionNode>
#           <ITEM>0</ITEM>
#         </InactionNode>
#       </ProcessNode>
#     </InputNode>
#   </ProcessNode>
# </ProcessNode>
# None <__main__.Variable instance at 0x104cef950> <__main__.Inaction instance at 0x104cef7e8>

# %%
example = "(W x* y bool) "+opString
tree = getTree(example, False)

for c in tree.child:
    print c.channel1, c.channel2, c.ty, c.process
    
ctx = Context()
ctx.env["x*"] =  TyQual( Linear(),   TySend( TyBool() ) )
ctx.env["y"] =  TyQual( Unlimited(),  TyRecv( TyBool(), TyBool()) )
octxt = typeCheck(tree, ctx)
# Out:
# <__main__.Channel instance at 0x104ca03b0> <__main__.Channel instance at 0x104ca0950> <__main__.TyBool instance at 0x104ca0710> <__main__.Inaction instance at 0x104dbb5a8>
# TypeChecking Process
# In Scope Restriction
# Dual Channels
# In Inaction
# ---- Result : TypeChecking Success ---
